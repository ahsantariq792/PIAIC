# %% [markdown]
#  # Shiekh Muhammad Ahsan Tariq
# ##PIAIC AI
# ##Batch 7
# ##Karachi
# ##PIAIC93475

# %%
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
print('all csv files in data directory:', glob.glob('C:\\Users\\ahsan/*.csv'))
# Out:
# all csv files in data directory: ['C:\\Users\\ahsan\\inventory.csv', 'C:\\Users\\ahsan\\states0.csv', 'C:\\Users\\ahsan\\states1.csv', 'C:\\Users\\ahsan\\states2.csv', 'C:\\Users\\ahsan\\states3.csv', 'C:\\Users\\ahsan\\states4.csv', 'C:\\Users\\ahsan\\states5.csv', 'C:\\Users\\ahsan\\states6.csv', 'C:\\Users\\ahsan\\states7.csv', 'C:\\Users\\ahsan\\states8.csv', 'C:\\Users\\ahsan\\states9.csv']

# %%
path = r'C:\Users\ahsan\States_folder'                     # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))     # advisable to use os.path.join as this makes concatenation OS independent

df_from_each_file = (pd.read_csv(f) for f in all_files)
us_census  = pd.concat(df_from_each_file, ignore_index=True)
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            5              Colorado   5278906   20.78438003220608%
# 6            0              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 12           0               Georgia  10006693   8.418242207460397%
# ...

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific              Income            GenderPop
# ...

# %%
us_census.columns
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.dtypes
# Out:
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %%
us_census.Income = us_census.Income.replace('[\$]', '', regex=True)
us_census.Income=pd.to_numeric(us_census.Income)
us_census.Income.head()
# Out:
# 0    43296.358603
# 1    70354.743902
# 2    54207.820955
# 3    41935.633968
# 4    67264.782303
# Name: Income, dtype: float64

# %%
separating_gender=us_census.GenderPop.str.split("_")
separating_gender.head()
# Out:
# 0      [2341093M, 2489527F]
# 1        [384160M, 349215F]
# 2      [3299088M, 3342840F]
# 3      [1451913M, 1506295F]
# 4    [19087135M, 19334329F]
# Name: GenderPop, dtype: object

# %%
us_census['Men'] = separating_gender.str.get(0)
us_census['Women'] = separating_gender.str.get(1)
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income            GenderPop        Men  \
# ...

# %%
us_census['Men']=us_census.Men.replace('M','',regex=True)
us_census['Women']=us_census.Women.replace('F','',regex=True)
us_census.Men=pd.to_numeric(us_census.Men)
us_census.Women=pd.to_numeric(us_census.Women)
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop             Hispanic                White  \
# 0           0     Alabama   4830620  3.7516156462584975%     61.878656462585%
# 1           1      Alaska    733375   5.909580838323351%  60.910179640718574%
# 2           2     Arizona   6641928  29.565921052631502%  57.120000000000026%
# 3           3    Arkansas   2958208   6.215474452554738%   71.13781021897813%
# 4           4  California  38421464  37.291874687968054%   40.21578881677474%
#
#                  Black                Native                Asian  \
# 0   31.25297619047618%   0.4532312925170065%  1.0502551020408146%
# 1  2.8485029940119775%    16.39101796407186%   5.450299401197604%
# 2  3.8509868421052658%     4.35506578947368%   2.876578947368419%
# 3  18.968759124087573%   0.5229197080291965%  1.1423357664233578%
# 4   5.677396405391911%  0.40529206190713685%  13.052234148776776%
#
#                 Pacific        Income            GenderPop       Men  \
# ...

# %%
us_census['Women']
# Out:
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334329.0
# 5      2630239.0
# 6      2630239.0
# 7      1841615.0
# 8       478041.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 19     1453125.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 23           NaN
# 24           NaN
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 31           NaN
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 40      353677.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# ...

# %%
us_census.fillna(value={"Women":us_census.TotalPop-us_census.Men},inplace=True)

us_census['Women']
# Out:
# 0      2489527.0
# 1       349215.0
# 2      3342840.0
# 3      1506295.0
# 4     19334329.0
# 5      2630239.0
# 6      2630239.0
# 7      1841615.0
# 8       478041.0
# 9       340810.0
# 10    10045763.0
# 11     5123362.0
# 12     5123362.0
# 13      696428.0
# 14      806083.0
# 15     6556862.0
# 16     3333382.0
# 17     1558931.0
# 18     1558931.0
# 19     1453125.0
# 20     2233145.0
# 21     2364097.0
# 22      679019.0
# 23     3057895.0
# 24     3057895.0
# 25     3455936.0
# 26     5038598.0
# 27     2727005.0
# 28     1536358.0
# 29     3081445.0
# 30     3081445.0
# 31      504536.0
# 32      939759.0
# 33     1390901.0
# 34      670717.0
# 35     4561386.0
# 36     4561386.0
# 37     1051703.0
# 38    10131373.0
# 39     5049925.0
# 40      353677.0
# 41     5913084.0
# 42     5913084.0
# 43     1942789.0
# 44     1990780.0
# 45     6534215.0
# 46     1869213.0
# 47      543273.0
# 48      543273.0
# 49     2455167.0
# 50      419713.0
# 51     3331859.0
# ...

# %%
us_census.drop_duplicates(subset=['State'],inplace=True)
us_census
# Out:
#     Unnamed: 0                 State  TotalPop             Hispanic  \
# 0            0               Alabama   4830620  3.7516156462584975%
# 1            1                Alaska    733375   5.909580838323351%
# 2            2               Arizona   6641928  29.565921052631502%
# 3            3              Arkansas   2958208   6.215474452554738%
# 4            4            California  38421464  37.291874687968054%
# 5            5              Colorado   5278906   20.78438003220608%
# 7            1           Connecticut   3593222  15.604830917874388%
# 8            2              Delaware    926454    8.82476635514019%
# 9            3  District of Columbia    647484   9.165921787709499%
# 10           4               Florida  19645772    21.3385426653884%
# 11           5               Georgia  10006693   8.418242207460397%
# 13           1                Hawaii   1406299   9.186708860759486%
# 14           2                 Idaho   1616547  11.505369127516781%
# ...

# %%
plt.scatter(us_census.Women,us_census.Income)
plt.show()

# %%
us_census.columns
us_census.dtypes
# Out:
# Unnamed: 0      int64
# State          object
# TotalPop        int64
# Hispanic       object
# White          object
# Black          object
# Native         object
# Asian          object
# Pacific        object
# Income        float64
# GenderPop      object
# Men             int64
# Women         float64
# dtype: object

# %%
us_census.Hispanic = us_census.Hispanic.replace('[\%]', '', regex=True)
us_census.White = us_census.White.replace('[\%]', '', regex=True)
us_census.Black = us_census.Black.replace('[\%]', '', regex=True)
us_census.Native = us_census.Native.replace('[\%]', '', regex=True)
us_census.Asian = us_census.Asian.replace('[\%]', '', regex=True)
us_census.Pacific = us_census.Pacific.replace('[\%]', '', regex=True)
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop            Hispanic               White  \
# 0           0     Alabama   4830620  3.7516156462584975     61.878656462585
# 1           1      Alaska    733375   5.909580838323351  60.910179640718574
# 2           2     Arizona   6641928  29.565921052631502  57.120000000000026
# 3           3    Arkansas   2958208   6.215474452554738   71.13781021897813
# 4           4  California  38421464  37.291874687968054   40.21578881677474
#
#                 Black               Native               Asian  \
# 0   31.25297619047618   0.4532312925170065  1.0502551020408146
# 1  2.8485029940119775    16.39101796407186   5.450299401197604
# 2  3.8509868421052658     4.35506578947368   2.876578947368419
# 3  18.968759124087573   0.5229197080291965  1.1423357664233578
# 4   5.677396405391911  0.40529206190713685  13.052234148776776
#
#                Pacific        Income            GenderPop       Men  \
# ...

# %%
us_census.Pacific.isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 37    False
# 38    False
# 39    False
# 40     True
# 41    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# Name: Pacific, dtype: bool

# %%
us_census.Pacific=pd.to_numeric(us_census.Pacific)
sensible_value=us_census.Pacific.mean()
us_census['Pacific'] = us_census['Pacific'].replace(np.nan,sensible_value )
us_census.Pacific
# Out:
# 0     0.034354
# 1     1.058683
# 2     0.167632
# 3     0.146861
# 4     0.351410
# 5     0.306500
# 7     0.018599
# 8     0.306500
# 9     0.029609
# 10    0.051510
# 11    0.046602
# 13    8.758861
# 14    0.127181
# 15    0.020032
# 16    0.032625
# 17    0.055164
# 19    0.306500
# 20    0.046438
# 21    0.039184
# 22    0.015670
# 23    0.036285
# 25    0.019809
# 26    0.019549
# 27    0.032909
# 28    0.015046
# 29    0.101657
# 31    0.072222
# 32    0.057143
# 33    0.574521
# 34    0.016096
# 35    0.031319
# 37    0.042771
# 38    0.023451
# 39    0.052326
# 40    0.306500
# 41    0.022645
# 43    0.106220
# 44    0.345333
# 45    0.019394
# 46    0.001240
# 47    0.035833
# 49    0.046978
# 50    0.041892
# 51    0.043156
# 52    0.068816
# 53    0.825983
# 55    0.030601
# 56    0.064715
# 57    0.609896
# 58    0.026446
# 59    0.020833
# Name: Pacific, dtype: float64

# %%
us_census.isnull()
# Out:
#     Unnamed: 0  State  TotalPop  Hispanic  White  Black  Native  Asian  \
# 0        False  False     False     False  False  False   False  False
# 1        False  False     False     False  False  False   False  False
# 2        False  False     False     False  False  False   False  False
# 3        False  False     False     False  False  False   False  False
# 4        False  False     False     False  False  False   False  False
# 5        False  False     False     False  False  False   False  False
# 7        False  False     False     False  False  False   False  False
# 8        False  False     False     False  False  False   False  False
# 9        False  False     False     False  False  False   False  False
# 10       False  False     False     False  False  False   False  False
# 11       False  False     False     False  False  False   False  False
# 13       False  False     False     False  False  False   False  False
# ...

# %%
us_census.reset_index(inplace=True)
us_census
# Out:
#     index  Unnamed: 0                 State  TotalPop            Hispanic  \
# 0       0           0               Alabama   4830620  3.7516156462584975
# 1       1           1                Alaska    733375   5.909580838323351
# 2       2           2               Arizona   6641928  29.565921052631502
# 3       3           3              Arkansas   2958208   6.215474452554738
# 4       4           4            California  38421464  37.291874687968054
# 5       5           5              Colorado   5278906   20.78438003220608
# 6       7           1           Connecticut   3593222  15.604830917874388
# 7       8           2              Delaware    926454    8.82476635514019
# 8       9           3  District of Columbia    647484   9.165921787709499
# 9      10           4               Florida  19645772    21.3385426653884
# 10     11           5               Georgia  10006693   8.418242207460397
# 11     13           1                Hawaii   1406299   9.186708860759486
# ...

# %%
us_census= us_census.drop('index', 1)

# %%
us_census=us_census.drop('Unnamed: 0',1)

# %%
us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop', 'Men', 'Women'],
#       dtype='object')

# %%
us_census
# Out:
#                    State  TotalPop            Hispanic               White  \
# 0                Alabama   4830620  3.7516156462584975     61.878656462585
# 1                 Alaska    733375   5.909580838323351  60.910179640718574
# 2                Arizona   6641928  29.565921052631502  57.120000000000026
# 3               Arkansas   2958208   6.215474452554738   71.13781021897813
# 4             California  38421464  37.291874687968054   40.21578881677474
# 5               Colorado   5278906   20.78438003220608   69.89557165861504
# 6            Connecticut   3593222  15.604830917874388    67.6770531400966
# 7               Delaware    926454    8.82476635514019   64.63271028037383
# 8   District of Columbia    647484   9.165921787709499  33.103910614525134
# 9                Florida  19645772    21.3385426653884   59.08374880153398
# 10               Georgia  10006693   8.418242207460397   54.28630556974962
# ...

# %%
plt.hist(us_census.Hispanic)
plt.show()

# %%
import pandas as pd
import numpy as np

# %%
data_df = pd.read_csv("inventory.csv")

# %%
data_df.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
staten_island = data_df.iloc[:10]
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
product_request = staten_island['product_description']
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
mask = (data_df['location'] == 'Brooklyn') & (data_df['product_type'] == 'seeds')
seed_request = data_df[mask]
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
data_df['in_stock'] = np.where(data_df['quantity'] > 0, True, False)
data_df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
data_df['total_value'] = data_df.price * data_df.quantity
data_df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type,
                     row.product_description)

# %%
data_df['full_description'] = data_df.apply(combine_lambda, axis = 1)

# %%
data_df
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...
